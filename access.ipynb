# %% [markdown]
# | Access Specifier | Same Class | Same Package | Subclass | Different Package |
# | ---------------- | ---------- | ------------ | -------- | ----------------- |
# | `public`         | ✔          | ✔            | ✔        | ✔                 |
# | `protected`      | ✔          | ✔            | ✔        | ❌                 |
# | default          | ✔          | ✔            | ❌        | ❌                 |
# | `private`        | ✔          | ❌            | ❌        | ❌                 |
